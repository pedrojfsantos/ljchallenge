# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sbrn

# %% [markdown]
# # Importing original dataset

# %%
dataset = pd.DataFrame(pd.read_excel('data/345e9990-8715-11eb-85f9-917cda200840Tech Careers Report PT 2021 - Raw Data.xlsx' ,sheet_name='TCS PT 2021 - raw data')).set_index('ID')

# %%
dataset
# Out:
#                        Employment_Status Employment_Status_Aggregated  \
# ID
# 1                     Employed full-time           Permanent Employee
# 2                     Employed full-time           Permanent Employee
# 3     Working as a Contractor/Freelancer                   Contractor
# 4                     Employed full-time           Permanent Employee
# 5                     Employed full-time           Permanent Employee
# ...                                  ...                          ...
# 3367                  Employed full-time           Permanent Employee
# 3368                  Employed full-time           Permanent Employee
# 3369                  Employed full-time           Permanent Employee
# 3370                  Employed full-time           Permanent Employee
# 3371  Working as a Contractor/Freelancer                   Contractor
#
#       Work_as_Contractor_12m  Work_as_Perm Residence_Country  \
# ID
# 1                        1.0           NaN          Portugal
# 2                        0.0           NaN          Portugal
# 3                        NaN           1.0          Portugal
# 4                        1.0           NaN          Portugal
# 5                        0.0           NaN          Portugal
# ...                      ...           ...               ...
# 3367                     0.0           NaN          Portugal
# 3368                     0.0           NaN          Portugal
# 3369                     0.0           NaN          Portugal
# 3370                     0.0           NaN          Portugal
# 3371                     NaN           0.0          Portugal
#
#      Residence_District Residence_District_Aggregated Work_Company_Country  \
# ID
# 1              Santarém                        Centre             Portugal
# 2               Coimbra                        Centre             Portugal
# 3                 Porto       Porto Metropolitan Area  No specific country
# 4                Açores            Azores and Madeira             Portugal
# 5                 Braga                         North             Portugal
# ...                 ...                           ...                  ...
# 3367              Porto       Porto Metropolitan Area             Portugal
# 3368             Lisboa      Lisbon Metropolitan Area             Portugal
# 3369              Porto       Porto Metropolitan Area              Germany
# 3370              Porto       Porto Metropolitan Area             Portugal
# 3371               Beja                         South                Italy
#
#      Work_Company_Continent Work_Company_PT_International  ... Citizenship  \
# ID                                                         ...
# 1                    Europe                      Portugal  ...  Portuguese
# 2                    Europe                      Portugal  ...  Portuguese
# 3                       NaN                 International  ...  Portuguese
# 4                    Europe                      Portugal  ...  Portuguese
# 5                    Europe                      Portugal  ...  Portuguese
# ...                     ...                           ...  ...         ...
# 3367                 Europe                      Portugal  ...  Portuguese
# 3368                 Europe                      Portugal  ...  Portuguese
# 3369                 Europe                 International  ...  Portuguese
# 3370                 Europe                      Portugal  ...  Portuguese
# 3371                 Europe                 International  ...  Portuguese
#
#      Birth_Year   Age  Gender                     English_Level Way_Into_Tech  \
# ID
# 1        1984.0  37.0    Male     Full professional proficiency    University
# 2        1976.0  45.0    Male     Full professional proficiency   Self-taught
# 3        1986.0  35.0    Male     Full professional proficiency    University
# 4        1975.0  46.0    Male     Full professional proficiency    University
# 5        1989.0  32.0    Male  Professional working proficiency    University
# ...         ...   ...     ...                               ...           ...
# 3367     1992.0  29.0    Male     Full professional proficiency   Self-taught
# 3368     1988.0  33.0    Male  Professional working proficiency    University
# 3369     1982.0  39.0    Male  Professional working proficiency    University
# 3370     1988.0  33.0    Male     Full professional proficiency    University
# 3371     1980.0  41.0    Male     Full professional proficiency    University
#
#       Way_Into_Tech_Other      Education_Level   Working_Experience  \
# ID
# 1                     NaN                  NaN    More than 9 years
# 2                     NaN                  NaN    More than 9 years
# 3                     NaN      Bachelor degree  Between 1 - 3 years
# 4                     NaN      Bachelor degree    More than 9 years
# 5                     NaN      Bachelor degree  Between 6 - 9 years
# ...                   ...                  ...                  ...
# 3367                  NaN  University drop out  Between 3 - 6 years
# 3368                  NaN  University drop out  Between 3 - 6 years
# 3369                  NaN  University drop out  Between 6 - 9 years
# 3370                  NaN  University drop out  Between 3 - 6 years
# 3371                  NaN  University drop out    More than 9 years
#
#      Working_Experience_Aggregated
# ID
# 1                         6+ years
# 2                         6+ years
# 3                      0 - 3 years
# 4                         6+ years
# 5                         6+ years
# ...                            ...
# 3367                   3 - 6 years
# 3368                   3 - 6 years
# 3369                      6+ years
# 3370                   3 - 6 years
# 3371                      6+ years
#
# [3371 rows x 125 columns]

# %%
print(dataset.columns)
# Out:
# Index(['Employment_Status', 'Employment_Status_Aggregated',
#        'Work_as_Contractor_12m', 'Work_as_Perm', 'Residence_Country',
#        'Residence_District', 'Residence_District_Aggregated',
#        'Work_Company_Country', 'Work_Company_Continent',
#        'Work_Company_PT_International',
#        ...
#        'Citizenship', 'Birth_Year', 'Age', 'Gender', 'English_Level',
#        'Way_Into_Tech', 'Way_Into_Tech_Other', 'Education_Level',
#        'Working_Experience', 'Working_Experience_Aggregated'],
#       dtype='object', length=125)

# %% [markdown]
# # Analysis for companies

# %%
comp_df=pd.DataFrame(dataset, columns=['Employer_Size','Employer_Org_Type', 'Avg_Salary', 'Changing_Jobs_next_6_months', 'Work_Company_Country'])
comp_df
# Out:
#                Employer_Size  \
# ID
# 1     1000 - 4.999 employees
# 2     Less than 10 employees
# 3     Less than 10 employees
# 4        100 - 499 employees
# 5          10 - 19 employees
# ...                      ...
# 3367       20 - 99 employees
# 3368     100 - 499 employees
# 3369  1000 - 4.999 employees
# 3370     100 - 499 employees
# 3371       20 - 99 employees
#
#                                       Employer_Org_Type  Avg_Salary  \
# ID
# 1                                             Corporate       32500
# 2     SME - Small or Medium Enterprise (personnel <250)       12500
# 3                        Startup (new business venture)       16000
# 4     SME - Small or Medium Enterprise (personnel <250)       17500
# 5     SME - Small or Medium Enterprise (personnel <250)       17500
# ...                                                 ...         ...
# 3367                                          Corporate       17500
# 3368  SME - Small or Medium Enterprise (personnel <250)       27500
# 3369                                          Corporate       32500
# 3370                                Consulting Business       22500
# 3371  SME - Small or Medium Enterprise (personnel <250)       43200
#
#       Changing_Jobs_next_6_months Work_Company_Country
# ID
# 1                             4.0             Portugal
# 2                             3.0             Portugal
# 3                             5.0  No specific country
# 4                             3.0             Portugal
# 5                             2.0             Portugal
# ...                           ...                  ...
# 3367                          3.0             Portugal
# 3368                          2.0             Portugal
# 3369                          3.0              Germany
# 3370                          5.0             Portugal
# 3371                          2.0                Italy
#
# [3371 rows x 5 columns]

# %%
plt.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-b7f23eb1f3b6> in <module>
# ----> 1 plt.plot(comp_df)
#
# AttributeError: module 'matplotlib' has no attribute 'plot'
